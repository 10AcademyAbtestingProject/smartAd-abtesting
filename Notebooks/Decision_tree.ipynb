# %%
# Importing Pandas an Numpy Libraries to use on manipulating our Data
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, mean_squared_error, r2_score, mean_absolute_error
import dvc.api
import io

import sys
sys.path.append("../")

from Scripts.modeling_pipeline import run_train_pipeline, get_pipeline, dvc_get_data

# %% [markdown]
# ## Steps to get the data
#
# 1. Make sure you are in sync with the latest main branch.
# 2. run `dvc pull` to get the latest data versions
# 3. In the next cell change the `version` and `path` to access the file you want.
#
# you can find the file names by exploring the data folder.
# For the versions, follow this:
#
#  - all files starting with `browser_` can be accessed starting from version=v1.1.1
#  - all files starting with `brand_` can be accessed starting from version=v1.1.2
#  - you can find the cleaned data with `device_make` converted to `brands` at version=v1.1
#  - you can find the cleaned raw data at version=v1
#  - you can find the raw data at version=v0
#
#
# The last 3 files have the same name `AdSmartABdata.csv`

# %%
df = dvc_get_data('Data/platform_os_6.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1226 entries, 0 to 1225
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   experiment   1226 non-null   object
#  1   hour         1226 non-null   int64
#  2   browser      1226 non-null   object
#  3   day_of_week  1226 non-null   object
#  4   brand        1226 non-null   object
#  5   response     1226 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 57.6+ KB

# %%
x = df.drop(columns=['response'])
y = df['response'].values

# %%
model = DecisionTreeClassifier()
str(model)
# Out:
# 'DecisionTreeClassifier()'

# %%
run_train_pipeline(model, x, y, 
                experiment_name='Decision Tree with cleaned data',
                run_name='platform_os_6_decision_tree')
# Out:
# Run - platform_os_6_decision_tree is logged to Experiment - Decision Tree with cleaned data
# {'accuracy': 0.51,
#  'precision': 0.46,
#  'recall': 0.41,
#  'entropy': 12.06,
#  'true_pos': 119,
#  'true_neg': 69,
#  'false_pos': 81,
#  'false_neg': 99}

# %%
df = dvc_get_data('Data/platform_os_5.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   experiment   17 non-null     object
#  1   hour         17 non-null     int64
#  2   browser      17 non-null     object
#  3   day_of_week  17 non-null     object
#  4   brand        17 non-null     object
#  5   response     17 non-null     int64
# dtypes: int64(2), object(4)
# memory usage: 944.0+ bytes

# %%
x = df.drop(columns=['response'])
y = df['response'].values

# %%
model = DecisionTreeClassifier()
str(model)
# Out:
# 'DecisionTreeClassifier()'

# %%
run_train_pipeline(model, x, y, 
                experiment_name='Decision tree with cleaned data',
                run_name='platform_os_5_decision_tree')
# Out:
# C:\Users\Stella\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Run - platform_os_5_decision_tree is logged to Experiment - Decision tree with cleaned data
# {'accuracy': 0.67,
#  'precision': 0.0,
#  'recall': 0.0,
#  'entropy': 11.51,
#  'true_pos': 4,
#  'true_neg': 0,
#  'false_pos': 0,
#  'false_neg': 2}

# %%
df = dvc_get_data('Data/browser_chrome_mobile.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 695 entries, 0 to 694
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   experiment    695 non-null    object
#  1   date          695 non-null    object
#  2   hour          695 non-null    int64
#  3   device_make   695 non-null    object
#  4   platform_os   695 non-null    int64
#  5   response      695 non-null    int64
#  6   date_of_week  695 non-null    object
# dtypes: int64(3), object(4)
# memory usage: 38.1+ KB

# %%
x = df.drop(columns=['response'])
y = df['response'].values

# %%
model = DecisionTreeClassifier()
str(model)
# Out:
# 'DecisionTreeClassifier()'

# %%
run_train_pipeline(model, x, y, 
                experiment_name='Decision tree with cleaned data',
                run_name='browser_chrome_mobile_decision_tree')
# Out:
# Run - browser_chrome_mobile_decision_tree is logged to Experiment - Decision tree with cleaned data
# {'accuracy': 0.53,
#  'precision': 0.44,
#  'recall': 0.29,
#  'entropy': 9.59,
#  'true_pos': 83,
#  'true_neg': 27,
#  'false_pos': 34,
#  'false_neg': 65}

# %%
df = dvc_get_data('Data/browser_samsung_internet.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   experiment    145 non-null    object
#  1   date          145 non-null    object
#  2   hour          145 non-null    int64
#  3   device_make   145 non-null    object
#  4   platform_os   145 non-null    int64
#  5   response      145 non-null    int64
#  6   date_of_week  145 non-null    object
# dtypes: int64(3), object(4)
# memory usage: 8.1+ KB

# %%
x = df.drop(columns=['response'])
y = df['response'].values

# %%
model = DecisionTreeClassifier()
str(model)
# Out:
# 'DecisionTreeClassifier()'

# %%
run_train_pipeline(model, x, y, 
                experiment_name='Decision tree with cleaned data',
                run_name='browser_samsung_internet_decision_tree')
# Out:
# Run - browser_samsung_internet_decision_tree is logged to Experiment - Decision tree with cleaned data
# {'accuracy': 0.55,
#  'precision': 0.52,
#  'recall': 0.52,
#  'entropy': 14.95,
#  'true_pos': 13,
#  'true_neg': 11,
#  'false_pos': 10,
#  'false_neg': 10}

# %%
df = dvc_get_data('Data/browser_facebook.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   experiment    156 non-null    object
#  1   date          156 non-null    object
#  2   hour          156 non-null    int64
#  3   device_make   156 non-null    object
#  4   platform_os   156 non-null    int64
#  5   response      156 non-null    int64
#  6   date_of_week  156 non-null    object
# dtypes: int64(3), object(4)
# memory usage: 8.7+ KB

# %%
x = df.drop(columns=['response'])
y = df['response'].values

# %%
model = DecisionTreeClassifier()
str(model)
# Out:
# 'DecisionTreeClassifier()'

# %%
run_train_pipeline(model, x, y, 
                experiment_name='Decision tree with cleaned data',
                run_name='browser_facebook_decision_tree')
# Out:
# Run - browser_facebook_decision_tree is logged to Experiment - Decision tree with cleaned data
# {'accuracy': 0.47,
#  'precision': 0.43,
#  'recall': 0.41,
#  'entropy': 16.21,
#  'true_pos': 13,
#  'true_neg': 9,
#  'false_pos': 12,
#  'false_neg': 13}
