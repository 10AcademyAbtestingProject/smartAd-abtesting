# %% [markdown]
# # Random Forest Model using sklearn

# %%
# Importing Pandas an Numpy Libraries to use on manipulating our Data
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

import sys
sys.path.append("../")

from Scripts.modeling_pipeline import run_train_pipeline, get_pipeline,dvc_get_data

# %%
df = dvc_get_data('Data/platform_os_6.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1226 entries, 0 to 1225
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   experiment   1226 non-null   object
#  1   hour         1226 non-null   int64
#  2   browser      1226 non-null   object
#  3   day_of_week  1226 non-null   object
#  4   brand        1226 non-null   object
#  5   response     1226 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 57.6+ KB

# %%
x = df.drop(columns=['response'])
y = df['response'].values

# %%
model = RandomForestClassifier()
str(model)
# Out:
# 'RandomForestClassifier()'

# %%
run_train_pipeline(model, x, y, 
                experiment_name='Random Forest with cleaned data',
                run_name='platform_os_6_random_forest')
# Out:
# {'accuracy': 0.49, 'precision': 0.43, 'recall': 0.42, 'entropy': 1.09, 'true_pos': 109, 'true_neg': 70, 'false_pos': 91, 'false_neg': 98}
# {'experiment': 0.04728765440867954, 'hour': 0.5810366607678898, 'browser': 0.10950122538678277, 'day_of_week': 0.2276652007076937, 'brand': 0.034509258728954086}
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# C:\Users\HEWANM~1\AppData\Local\Temp/ipykernel_2192/762836589.py in <module>
# ----> 1 run_train_pipeline(model, x, y,
#       2                 experiment_name='Random Forest with cleaned data',
#       3                 run_name='platform_os_6_random_forest')
#
# ~\smartAd-abtesting\Notebooks\..\Scripts\modeling_pipeline.py in run_train_pipeline(model, x, y, experiment_name, run_name)
#     229
#     230     train_pipeline.fit(X_train, y_train)
# --> 231     return train_pipeline.log_model('model', X_test, y_test, experiment_name, run_name, run_params=run_params)
#
# ~\smartAd-abtesting\Notebooks\..\Scripts\modeling_pipeline.py in log_model(self, model_key, X_test, y_test, experiment_name, run_name, run_params)
#      97         # mlflow.set_experiment(experiment_name)
#      98         # mlflow.set_tracking_uri('http://localhost:5000')
# ---> 99         # with mlflow.start_run(run_name=run_name):
#     100         #     if run_params:
#     101         #         for name in run_params:
#
# C:\ProgramData\Anaconda3\lib\site-packages\mlflow\tracking\fluent.py in start_run(run_id, experiment_id, run_name, nested, tags, description)
#     235     experiment_id = str(experiment_id) if isinstance(experiment_id, int) else experiment_id
#     236     if len(_active_run_stack) > 0 and not nested:
# --> 237         raise Exception(
#     238             (
#     239                 "Run with UUID {} is already active. To start a new run, first end the "
#
# Exception: Run with UUID 2456b512693e414999696a6fb759fd6a is already active. To start a new run, first end the current run with mlflow.end_run(). To start a nested run, call start_run with nested=True
